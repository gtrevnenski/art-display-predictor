# %%
import numpy as np
from pathlib import Path
from catboost import CatBoostClassifier, Pool

splits_dir = Path("../data/splits_MiniLM-L6-v2")

# Load TRAIN only (no val.npz)
train = np.load(splits_dir / "train.npz", allow_pickle=True)

# Load feature names first
feature_columns = np.load(
    splits_dir / "feature_columns.npy",
    allow_pickle=True
).tolist()

# Identify categorical features
categorical_features = ["department", "country", "cat1", "subcat1", "cat2"]
cat_indices = [i for i, col in enumerate(feature_columns) if col in categorical_features]
print(f"Categorical features at indices: {cat_indices}")

# Keep as object dtype to preserve categorical features
X = train["X"]
y = train["y"].astype(int)


X = X.copy()  # avoid modifying underlying mmap if any
for i, col in enumerate(feature_columns):
    if col not in ["department", "country", "cat1", "subcat1", "cat2", "objectEndDate"]:
        X[:, i] = X[:, i].astype(np.float32)


# --- create validation subset FROM TRAIN (for HPO only) ---
rng = np.random.default_rng(42)
val_frac = 0.2

idx_all = np.arange(X.shape[0])
rng.shuffle(idx_all)

n_val = int(val_frac * X.shape[0])
idx_val = idx_all[:n_val]
idx_train = idx_all[n_val:]

X_train, y_train = X[idx_train], y[idx_train]
X_val,   y_val   = X[idx_val],   y[idx_val]

print("Train split:", X_train.shape, y_train.shape)
print("Val split:  ", X_val.shape,   y_val.shape)

# --- subsample up to 20k FROM TRAIN SPLIT ---
n_samples = min(20_000, X_train.shape[0])
idx_sub = rng.choice(X_train.shape[0], size=n_samples, replace=False)

X_sub = X_train[idx_sub]
y_sub = y_train[idx_sub]

# --- print positives ratio in subsample ---
pos_ratio = float(y_sub.mean())
print(f"Subsample positives ratio: {pos_ratio:.4f} ({int(y_sub.sum())}/{y_sub.shape[0]})")

train_pool_sub = Pool(
    X_sub,
    y_sub,
    feature_names=feature_columns,
    cat_features=cat_indices
)

print("Subsampled tuning set:", X_sub.shape, y_sub.shape)
# Out:
# Categorical features at indices: [2, 3, 4, 5, 6]
# Train split: (280552, 391) (280552,)
# Val split:   (70138, 391) (70138,)
# Subsample positives ratio: 0.1077 (2155/20000)
# Subsampled tuning set: (20000, 391) (20000,)

# %%
param_dist = {
    "depth":            [6, 8, 10],
    "learning_rate":    [0.05, 0.08, 0.1],
    "l2_leaf_reg":      [3, 5, 7],
    "random_strength":  [0.5, 1.0, 2.0],
    "border_count":     [64, 128],
    "iterations":       [500]
}

# %%
model = CatBoostClassifier(
    loss_function="Logloss",
    eval_metric="AUC",
    task_type="CPU",
    thread_count=4,
    bagging_temperature=1.0,
    verbose=False,
)

search_result = model.randomized_search(
    param_distributions=param_dist,
    X=train_pool_sub,
    cv=3,                         # 3-fold CV on the subsample
    n_iter=25,                    # number of random combinations to try
    partition_random_seed=42,
    search_by_train_test_split=False,  # use CV, not a single split
    calc_cv_statistics=True,
    refit=True,                   # refit model on all X_sub, y_sub with best params
    shuffle=True,
    verbose=True,
)
# Out:
# Training on fold [0/3]
#
# bestTest = 0.9644444164
# bestIteration = 498
#
# Training on fold [1/3]
#
# bestTest = 0.970798569
# bestIteration = 472
#
# Training on fold [2/3]
#
# bestTest = 0.9672764001
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.9674828	best: 0.9674828 (0)	total: 4m 50s	remaining: 1h 56m 14s
# Training on fold [0/3]
#
# bestTest = 0.9640151768
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9706725933
# bestIteration = 482
#
# Training on fold [2/3]
#
# bestTest = 0.9679095569
# bestIteration = 497
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.9674627	best: 0.9674828 (0)	total: 15m 59s	remaining: 3h 3m 48s
# Training on fold [0/3]
#
# bestTest = 0.9647078985
# bestIteration = 462
#
# Training on fold [1/3]
#
# ...

# %%
print("Best params from search:")
print(search_result["params"])
print("Best CV AUC:", max(search_result["cv_results"]["test-AUC-mean"]))
# Out:
# Best params from search:
# {'border_count': 128, 'random_strength': 1, 'depth': 10, 'learning_rate': 0.1, 'l2_leaf_reg': 5, 'iterations': 500}
# Best CV AUC: 0.9702741849785914
