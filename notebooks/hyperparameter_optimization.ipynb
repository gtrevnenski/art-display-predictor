# %%
import numpy as np
from pathlib import Path
from catboost import CatBoostClassifier, Pool

splits_dir = Path("../data/splits")

train = np.load(splits_dir / "train.npz", allow_pickle=True)
val   = np.load(splits_dir / "val.npz",   allow_pickle=True)

# Cast X to float32, y to int
X_train = train["X"].astype(np.float32)
y_train = train["y"].astype(int)

X_val   = val["X"].astype(np.float32)
y_val   = val["y"].astype(int)

feature_columns = np.load(
    splits_dir / "feature_columns.npy",
    allow_pickle=True
).tolist()

# Combine train + val for tuning (optional but common)
X_tune = np.concatenate([X_train, X_val], axis=0)
y_tune = np.concatenate([y_train, y_val], axis=0)

print("Tuning set:", X_tune.shape, y_tune.shape)
# Out:
# Tuning set: (412577, 773) (412577,)

# %%
rng = np.random.default_rng(42)
n_samples = min(20_000, X_tune.shape[0])  # cap to 100k for speed

idx_sub = rng.choice(X_tune.shape[0], size=n_samples, replace=False)

X_sub = X_tune[idx_sub]
y_sub = y_tune[idx_sub]

train_pool_sub = Pool(X_sub, y_sub, feature_names=feature_columns)
print("Subsampled tuning set:", X_sub.shape, y_sub.shape)
# Out:
# Subsampled tuning set: (20000, 773) (20000,)

# %%
param_dist = {
    "depth":            [4, 6, 8, 10],
    "learning_rate":    [0.03, 0.05, 0.08],
    "l2_leaf_reg":      [1, 3, 5, 7, 10],
    # "bagging_temperature": [0, 0.25, 0.5, 1.0],
    "random_strength":  [0.5, 1.0, 2.0],
    "border_count":     [64, 128],
    "iterations":       [500]
}

# %%
model = CatBoostClassifier(
    loss_function="Logloss",
    eval_metric="AUC",
    task_type="CPU",
    bagging_temperature=1.0,
    verbose=False,
)

search_result = model.randomized_search(
    param_distributions=param_dist,
    X=train_pool_sub,
    cv=3,                         # 3-fold CV on the subsample
    n_iter=25,                    # number of random combinations to try
    partition_random_seed=42,
    search_by_train_test_split=False,  # use CV, not a single split
    calc_cv_statistics=True,
    refit=True,                   # refit model on all X_sub, y_sub with best params
    shuffle=True,
)
# Out:
# Training on fold [0/3]
#
# bestTest = 0.9595733975
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9633131583
# bestIteration = 495
#
# Training on fold [2/3]
#
# bestTest = 0.9662699985
# bestIteration = 485
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.9630219	best: 0.9630219 (0)	total: 2m 12s	remaining: 52m 59s
# Training on fold [0/3]
#
# bestTest = 0.964651778
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9658940429
# bestIteration = 474
#
# Training on fold [2/3]
#
# bestTest = 0.9677203239
# bestIteration = 486
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.9660043	best: 0.9660043 (1)	total: 4m 19s	remaining: 49m 40s
# Training on fold [0/3]
#
# bestTest = 0.9599302676
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9623548431
# bestIteration = 488
#
# Training on fold [2/3]
#
# bestTest = 0.967179575
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.9631489	best: 0.9660043 (1)	total: 6m 28s	remaining: 47m 29s
# Training on fold [0/3]
#
# bestTest = 0.962036396
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9646645064
# bestIteration = 487
#
# Training on fold [2/3]
#
# bestTest = 0.968841203
# bestIteration = 496
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.9651323	best: 0.9660043 (1)	total: 8m 45s	remaining: 45m 58s
# Training on fold [0/3]
#
# bestTest = 0.9639414876
# bestIteration = 494
#
# Training on fold [1/3]
#
# bestTest = 0.9663563086
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9685434045
# bestIteration = 497
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.9662568	best: 0.9662568 (4)	total: 10m 55s	remaining: 43m 41s
# Training on fold [0/3]
#
# bestTest = 0.9652114693
# bestIteration = 498
#
# Training on fold [1/3]
#
# bestTest = 0.965715132
# bestIteration = 495
#
# Training on fold [2/3]
#
# bestTest = 0.9692191919
# bestIteration = 478
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.9666963	best: 0.9666963 (5)	total: 13m	remaining: 41m 12s
# Training on fold [0/3]
#
# bestTest = 0.9584204691
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9622225632
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9653065255
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 6:	loss: 0.9619832	best: 0.9666963 (5)	total: 15m 10s	remaining: 39m 2s
# Training on fold [0/3]
#
# bestTest = 0.9651805406
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9686550279
# bestIteration = 460
#
# Training on fold [2/3]
#
# bestTest = 0.9708277563
# bestIteration = 496
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 7:	loss: 0.9681963	best: 0.9681963 (7)	total: 22m 36s	remaining: 48m 3s
# Training on fold [0/3]
#
# bestTest = 0.9640792394
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9694177783
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.970727578
# bestIteration = 487
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 8:	loss: 0.9680696	best: 0.9681963 (7)	total: 30m 5s	remaining: 53m 29s
# Training on fold [0/3]
#
# bestTest = 0.9658407503
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9680809429
# bestIteration = 481
#
# Training on fold [2/3]
#
# bestTest = 0.9710861736
# bestIteration = 490
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 9:	loss: 0.9682862	best: 0.9682862 (9)	total: 37m 32s	remaining: 56m 18s
# Training on fold [0/3]
#
# bestTest = 0.9642813469
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.967536597
# bestIteration = 492
#
# Training on fold [2/3]
#
# bestTest = 0.9710830802
# bestIteration = 495
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 10:	loss: 0.9676175	best: 0.9682862 (9)	total: 1h 16m 16s	remaining: 1h 37m 4s
# Training on fold [0/3]
#
# bestTest = 0.9640361771
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9679722165
# bestIteration = 496
#
# Training on fold [2/3]
#
# bestTest = 0.9711111587
# bestIteration = 476
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 11:	loss: 0.9676995	best: 0.9682862 (9)	total: 1h 54m 45s	remaining: 2h 4m 19s
# Training on fold [0/3]
#
# bestTest = 0.9638293114
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9664061515
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9696235935
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 12:	loss: 0.9666197	best: 0.9682862 (9)	total: 2h 33m 21s	remaining: 2h 21m 34s
# Training on fold [0/3]
#
# bestTest = 0.9653015196
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9687223574
# bestIteration = 477
#
# Training on fold [2/3]
#
# bestTest = 0.9703330514
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 13:	loss: 0.9680983	best: 0.9682862 (9)	total: 3h 11m 53s	remaining: 2h 30m 46s
# Training on fold [0/3]
#
# bestTest = 0.9578095075
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9637621009
# bestIteration = 497
#
# Training on fold [2/3]
#
# bestTest = 0.9657587558
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 14:	loss: 0.9624330	best: 0.9682862 (9)	total: 3h 12m 45s	remaining: 2h 8m 30s
# Training on fold [0/3]
#
# bestTest = 0.9588539473
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9608759734
# bestIteration = 495
#
# Training on fold [2/3]
#
# bestTest = 0.9645931415
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 15:	loss: 0.9614350	best: 0.9682862 (9)	total: 3h 13m 39s	remaining: 1h 48m 55s
# Training on fold [0/3]
#
# bestTest = 0.9591568111
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9608175656
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9652495357
# bestIteration = 492
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 16:	loss: 0.9617166	best: 0.9682862 (9)	total: 3h 14m 33s	remaining: 1h 31m 33s
# Training on fold [0/3]
#
# bestTest = 0.9615785316
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9628004549
# bestIteration = 490
#
# Training on fold [2/3]
#
# bestTest = 0.9651805292
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 17:	loss: 0.9631570	best: 0.9682862 (9)	total: 3h 15m 24s	remaining: 1h 15m 59s
# Training on fold [0/3]
#
# bestTest = 0.9593623683
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9605095867
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.96402479
# bestIteration = 492
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 18:	loss: 0.9612785	best: 0.9682862 (9)	total: 3h 16m 16s	remaining: 1h 1m 58s
# Training on fold [0/3]
#
# bestTest = 0.9624031395
# bestIteration = 491
#
# Training on fold [1/3]
#
# bestTest = 0.9653190062
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.968158634
# bestIteration = 493
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 19:	loss: 0.9652790	best: 0.9682862 (9)	total: 3h 18m 22s	remaining: 49m 35s
# Training on fold [0/3]
#
# bestTest = 0.9592729128
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9627889161
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9658759478
# bestIteration = 499
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 20:	loss: 0.9626459	best: 0.9682862 (9)	total: 3h 20m 29s	remaining: 38m 11s
# Training on fold [0/3]
#
# bestTest = 0.9640843546
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9673899234
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.970054289
# bestIteration = 496
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 21:	loss: 0.9671595	best: 0.9682862 (9)	total: 3h 27m 54s	remaining: 28m 21s
# Training on fold [0/3]
#
# bestTest = 0.9604907916
# bestIteration = 495
#
# Training on fold [1/3]
#
# bestTest = 0.9654086995
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9694523861
# bestIteration = 480
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 22:	loss: 0.9650998	best: 0.9682862 (9)	total: 3h 35m 32s	remaining: 18m 44s
# Training on fold [0/3]
#
# bestTest = 0.9616982021
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9661239862
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.9704476259
# bestIteration = 488
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 23:	loss: 0.9660864	best: 0.9682862 (9)	total: 3h 43m	remaining: 9m 17s
# Training on fold [0/3]
#
# bestTest = 0.9643344016
# bestIteration = 499
#
# Training on fold [1/3]
#
# bestTest = 0.9679481872
# bestIteration = 499
#
# Training on fold [2/3]
#
# bestTest = 0.970452266
# bestIteration = 497
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 24:	loss: 0.9675719	best: 0.9682862 (9)	total: 4h 21m 47s	remaining: 0us

# %%
print("Best params from search:")
print(search_result["params"])
print("Best CV AUC:", max(search_result["cv_results"]["test-AUC-mean"]))
# Out:
# Best params from search:
# {'border_count': 64, 'random_strength': 2, 'depth': 8, 'learning_rate': 0.08, 'l2_leaf_reg': 5, 'iterations': 500}
# Best CV AUC: 0.9682862288999282
