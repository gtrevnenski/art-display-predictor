# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import numpy as np

df_train = pd.read_parquet("../data/df_train_clean.parquet")
print(df_train.head())
# Out:
#    objectBeginDate classification  accessionYear  \
# 0             1815        Daggers         1881.0
# 1             1360      Paintings         1975.0
# 2             1700          Glass         1975.0
# 3             1750          Glass         1975.0
# 4             1575          Glass         1975.0
#
#                                          objectDate  \
# 0                                       ca. 1840–50
# 1                                          ca. 1365
# 2  18th century, reassembled last half 19th century
# 3                          second half 18th century
# 4                                 late 16th century
#
#                      objectName                                culture  \
# 0  Dagger (Kindjal) with sheath  Caucasian, possibly northern Dagestan
# 1                      Painting
# 2                      Figurine               probably French (Nevers)
# 3                         Panel      probably Bohemia or Lower Austria
# 4                        Plaque                                Italian
#
#                                               medium  \
# 0                        Steel, wood, silver, niello
# 1                       Tempera on wood, gold ground
# 2  Figures of lampworked glass (opaque white, pal...
# 3  Colorless nonlead glass. Cut, polished, revers...
# 4  Rock crystal. Cut, polished, reverse painted, ...
#
#                                title  isTimelineWork  \
# 0       Dagger (Kindjal) with Sheath            True
# 1                         Six Angels           False
# 2               The Finding of Moses           False
# 3  A Female Saint (possibly Rosalia)           False
# 4                     The Deposition           False
#
#                  department  isPublicDomain  objectID  objectEndDate  \
# 0            Arms and Armor            True     24991           1875
# 1  Robert Lehman Collection            True    459006           1370
# 2  Robert Lehman Collection            True    460813           1900
# 3  Robert Lehman Collection            True    461279           1800
# 4  Robert Lehman Collection            True    461472           1600
#
#                                  creditLine  label_isOnView  \
# 0  Bequest of Stephen Whitney Phoenix, 1881            True
# 1            Robert Lehman Collection, 1975            True
# 2            Robert Lehman Collection, 1975            True
# 3            Robert Lehman Collection, 1975            True
# 4            Robert Lehman Collection, 1975            True
#
#                                             text_all
# 0  Dagger (Kindjal) with Sheath Dagger (Kindjal) ...
# 1  Six Angels Painting Tempera on wood, gold grou...
# 2  The Finding of Moses Figurine Figures of lampw...
# 3  A Female Saint (possibly Rosalia) Panel Colorl...
# 4  The Deposition Plaque Rock crystal. Cut, polis...

# %%
import torch
import numpy as np
import pandas as pd
from pathlib import Path
from sentence_transformers import SentenceTransformer

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

model = SentenceTransformer("intfloat/e5-large-v2", device=device)

texts = df_train["text_all"].tolist()

embeddings = model.encode(
    texts,
    batch_size=32,
    show_progress_bar=True,
    convert_to_numpy=True,
)

print("Embeddings shape:", embeddings.shape)
# Out:
# Using device: cuda
# Batches:   0%|          | 0/15169 [00:00<?, ?it/s]
# Embeddings shape: (485385, 1024)

# %%
out_dir = Path("../data")
out_dir.mkdir(parents=True, exist_ok=True)

# 1) Save embeddings only
np.save(out_dir / "embeddings_text_all_e5large.npy", embeddings)

# 2) Save metadata (IDs + label + numeric + boolean)
NUMERIC = ["objectBeginDate", "objectEndDate", "accessionYear"]
BOOLEAN = ["isTimelineWork", "isPublicDomain"]

meta_cols = ["objectID", "label_isOnView"] + NUMERIC + BOOLEAN
df_meta = df_train[meta_cols].reset_index(drop=True)

df_meta.to_parquet(out_dir / "meta_for_model_e5large.parquet", index=False)

print("Saved embeddings and meta.")
# Out:
# Saved embeddings and meta.
